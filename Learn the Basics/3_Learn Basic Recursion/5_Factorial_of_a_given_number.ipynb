# %%
n = 5

for i in range(1,n+1):
    
    n = n * (n - i)
    
print(n)

# %%
fact = 0
N = 5

for i in range(N,0,-1):
    
    fact = N * (N-1)
    
print(fact)

# %%
fact = 1
X = 5

for i in range(1,X+1):
    
    fact = fact * i
    
print(fact)

# %% [markdown]
# ### try to loop forward and backward both sides and decide which works out for the program

# %%
def fact(n):
    
    if n == 0 or n == 1:
        return 1
    
    return n * fact(n-1)

fact(5)
