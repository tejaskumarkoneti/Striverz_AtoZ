# %%
N = 5
sum = 0

for i in range(1,N+1):
    
    sum = sum + i
    
print(sum)
# Out:
# 15

# %%
N = 5

sum = N * (N+1) // 2

print(sum)
# Out:
# 15

# %%
def res(n):
    
    if n == 0:
        return 0
    
    return n + res(n-1)

r = res(5)
print(r)
# Out:
# 15
