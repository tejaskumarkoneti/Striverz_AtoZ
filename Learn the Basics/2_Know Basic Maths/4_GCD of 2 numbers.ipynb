# %%
N1 = 69
N2 = 25
print("GCD of {} and {} is :".format(N1,N2))

for i in range(N2):

    if N2 == 0:
        print(N1)
        
    if N1 > N2:
        r1 = N1  % N2
        N1,N2 = N2,r1
    
    else:
        r2 = N2 % N1
        N1,N2 = N2,r2
        
print(N1)
# Out:
# GCD of 69 and 25 is :
# 1
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[26], line 11
#       8     print(N1)
#      10 if N1 > N2:
# ---> 11     r1 = N1  % N2
#      12     N1,N2 = N2,r1
#      14 else:
#
# ZeroDivisionError: integer modulo by zero

# %%
N1 = 69
N2 = 25
print("GCD of {} and {} is :".format(N1,N2))

for i in range(N2):
    
    if N2 == 0:
        break       
    elif N1 > N2:
        r1 = N1  % N2
        N1,N2 = N2,r1
    
    elif N2 > N1:
        r2 = N2 % N1
        N1,N2 = N2,r2

print(N1)
# Out:
# GCD of 69 and 25 is :
# 1

# %% [markdown]
# ### 26/2/26

# %%
# Brute Force

# %%
# Optimal Approach

# %% [markdown]
# ### 2/3/26

# %%
# Brute Force

# %%
# Optimal Approach
